# %%
import csv
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from scipy.stats import poisson
import math
from random import randrange

# %%
f = open('../data/collisions_new.csv')
raw_data = csv.DictReader(f)
data = list(raw_data)
f.close()
print len(data)
data = [i for i in data if i['lat'] != '' and i['lon'] != '' and i['collisions'] != '']
print len(data)
# Out:
# 249462
# 247573

# %%
# Just Manhattan
collisions_count = {}
for incident in data:
    if int(incident['borocode']) == 1:
        lon = incident['lon']
        lat = incident['lat']
        c_count = incident['collisions']
        count = collisions_count.get((lon, lat), 0)
        collisions_count[(lon, lat)] = count + int(c_count)

# %%
FACTOR = 0.7581
x_coords = []
y_coords = []
counts = []

for x,y in collisions_count.keys():
    x_coords.append(float(x))
    y_coords.append(float(y))
    counts.append(float(collisions_count[(x,y)]))

loc = np.transpose(np.array([x_coords,y_coords])) # original lats and lons, haven't applied scaling factor
counts = np.array(counts)

# %%
print 'Total intersections: %d' % len(counts)
print 'Average collisions per interesection: %.2f' % (sum(counts) / float(len(counts)))

log_counts = np.log(counts)
plt.hist(log_counts, normed=False, bins=30)
plt.show()
# Out:
# Total intersections: 4191
# Average collisions per interesection: 21.54

# %%
plt.scatter(loc[:,0], loc[:,1])
plt.show()

# %% [markdown]
# #### Done with processing, getting to work

# %%
# Irene's cross-validation code
def shuffle(x):
    for i in xrange(len(x)-1, 0, -1):
        j = randrange(i + 1)
        x[i], x[j] = x[j], x[i]
    return x
        
def flatten_list(list_of_lists):
        return [item for sublist in list_of_lists for item in sublist]

def split_groups(lst, n):
    return [lst[i::n] for i in xrange(n)]

# k-fold cross validation
# usage: fit first, then call split_train_test(index=2) to get the different splittings of test/train data
class CrossValidation(object):
    def __init__(self, folds=5):
        self.folds = folds
    
    def flatten_list(self, list_of_lists):
        return [item for sublist in list_of_lists for item in sublist]
    
    def fit(self, locations, counts):
        self.locations = np.array(locations)
        self.counts = np.array(counts)
        self.cross_validation_data = {}
        self.n = len(locations)
        
        indicies = range(self.n)
        shuffled_indicies = shuffle(indicies)
        
        groups = np.array(split_groups(shuffled_indicies, self.folds))
        
        for fld in xrange(self.folds):
#            fold_data = {}
#            train_indicies = range(self.folds).remove(fld)
            fold_data = {}
            train_indicies = range(self.folds)
            train_indicies.remove(fld)

            test_indicies = fld
            train_set = self.flatten_list(groups[train_indicies])

#            train_set = self.flatten_list(groups[train_indicies][0])
            test_set = groups[test_indicies]
    
            fold_data['train'] = list(train_set)
            fold_data['test'] = test_set
            self.cross_validation_data[fld] = fold_data
        
    def split_train_test(self, index=0):
        if index >= self.folds:
            print 'Index too big'
            return
        else:
            fold_data = self.cross_validation_data[index]
            train = fold_data['train']
            test = fold_data['test']
            
            return self.locations[train], self.locations[test], self.counts[train], self.counts[test]

# %% [markdown]
# #### Using log counts

# %%
cross_valid = CrossValidation(folds=10)
cross_valid.fit(loc, log_counts)

# %%
# Later we'll turn this into a for loop
loc_train, loc_test, counts_train, counts_test = cross_valid.split_train_test(index=0)
print np.shape(loc_train)
print np.shape(loc_test)
# Out:
# (3771L, 2L)
# (420L, 2L)

# %%
# usage: create object, fit, predict
class Kriging(object):
    def __init__(self, kernel='matern_3', length_scale = 0.1, sigma_y = 1, sigma_f = 5):
        self.kernel = kernel
        self.length_scale = length_scale
        self.sigma_y = sigma_y
        self.sigma_f = sigma_f
        self.locations = None
        self.n = None
        self.yd = None
        self.FACTOR = 0.7581
        self.earth_radius = 3959 # in miles

    def fit(self, locations, counts):
        self.locations = locations
        self.n = len(locations)
        self.yd = counts

    def predict(self, new_sites):
        Kdd = self.build_kernel_matrix(self.locations, self.locations)
#        Kpp = self.build_kernel_matrix(new_sites, new_sites)
        Kpd = self.build_kernel_matrix(new_sites, self.locations)
        Kdd = self.sigma_f**2*Kdd + self.sigma_y**2*np.eye(np.size(self.locations)/2)
#        Kpp = self.sigma_f**2*Kpp + self.sigma_y**2*np.eye(np.size(new_sites)/2)
        Kpd = self.sigma_f**2*Kpd
        yp_mean = np.dot(np.dot(Kpd,np.linalg.inv(Kdd)),self.yd)
#        yp_sigma = np.diag(Kpp - np.dot(np.dot(Kpd,np.linalg.inv(Kdd)),Kpd.T))        
        return yp_mean

    def variances(self, new_sites):
        Kdd = self.build_kernel_matrix(self.locations, self.locations)
        Kpp = self.build_kernel_matrix(new_sites, new_sites)
        Kpd = self.build_kernel_matrix(new_sites, self.locations)
        Kdd = self.sigma_f**2*Kdd + self.sigma_y**2*np.eye(np.size(self.locations)/2)
        Kpp = self.sigma_f**2*Kpp + self.sigma_y**2*np.eye(np.size(new_sites)/2)
        Kpd = self.sigma_f**2*Kpd
#        yp_mean = np.dot(np.dot(Kpd,np.linalg.inv(Kdd)),self.yd)
        yp_vars = np.diag(Kpp - np.dot(np.dot(Kpd,np.linalg.inv(Kdd)),Kpd.T))        
        return yp_vars
        
    
    def build_kernel_matrix(self, locs1, locs2):
        return self.kernel_function(self.build_distance_matrix(locs1, locs2))

    def build_distance_matrix(self, locs1, locs2):
        lons1, lats1 = locs1[:,0], locs1[:,1]
        lons2, lats2 = locs2[:,0], locs2[:,1]
        dlon12 = lons2 - lons1[:, None]
        dlat12 = lats2 - lats1[:, None]
        D12 = np.sqrt(np.square(dlon12*self.FACTOR) + np.square(dlat12))
        D12 = D12/360*(2*math.pi)*self.earth_radius
        return D12

    def kernel_function(self, x):
        if self.kernel == 'matern_1':
            return self.matern_1(x,self.length_scale)
        elif self.kernel == 'matern_3':
            return self.matern_3(x,self.length_scale)
        else:
            return self.matern_5(x,self.length_scale)        
    
    def matern_1(self,x,L):
        return np.exp(-x/L)
    
    def matern_3(self,x,L):
        return (1+math.sqrt(3)*x/L)*np.exp(-math.sqrt(3)*x/L)
    
    def matern_5(self,x,L):
        return (1+math.sqrt(5)*x/L+5*np.square(x)/(3*L*L))*np.exp(-math.sqrt(5)*x/L)

# neigh = KNeighbors(n_neighbors=8, weights='uniform')
# neigh.fit(loc_train, counts_train)
# predictions = neigh.predict(loc_test)

# %%
np.size(loc_train)
# Out:
# 7542

# %%
kriger = Kriging(kernel='matern_3', length_scale=0.1, sigma_y = 1, sigma_f = 5)
kriger.fit(loc_train, counts_train)
predictions = kriger.predict(loc_test)

# %%
predictions
# Out:
# array([  1.97902884e+00,   3.32901492e+00,   2.78442343e+00,
#          1.84571280e+00,   3.43524008e+00,   2.75005217e+00,
#          3.42190397e+00,   6.42644391e-01,   3.39140249e+00,
#          3.41234583e+00,   2.44329264e+00,   2.09027717e+00,
#          2.06401540e+00,   1.62205601e+00,   7.61525873e-01,
#          3.31245437e+00,   1.03912193e+00,   2.07627631e+00,
#          3.23812806e-01,   2.22316220e+00,   3.35605921e+00,
#          3.26174734e+00,   2.55342461e+00,   3.10495043e+00,
#          1.87870494e+00,   1.97405267e+00,   8.07039424e-01,
#          1.57825751e+00,   1.62198407e+00,   3.32336612e+00,
#          3.65766228e+00,   1.38934802e-01,   3.23821496e+00,
#          2.39978988e+00,   2.27749753e+00,   1.45681694e+00,
#          9.37441792e-01,   2.35962663e+00,   3.04288773e+00,
#          2.28164392e+00,   1.11763855e+00,   6.26596458e-01,
#          9.55011821e-01,   1.62942303e+00,   3.78769259e+00,
#          3.26251530e+00,   2.81217539e+00,   3.36558419e+00,
#          3.18353138e+00,   5.02846337e+00,   2.16582678e+00,
#          2.01350207e+00,   2.00473114e+00,   1.48778906e+00,
#          1.15475094e+00,   2.62828495e+00,   1.84602154e+00,
#          3.70174346e+00,   1.61744485e+00,   1.04023513e+00,
#          2.95312531e+00,   2.67674137e+00,   2.94995885e+00,
#          8.98874985e-01,   1.53352202e+00,   2.08799767e+00,
#          2.95313358e+00,   2.79751330e+00,   2.41025564e+00,
#          4.31269679e+00,   2.69214746e+00,   2.60493420e+00,
#          1.74603208e+00,   7.51607867e-01,   2.34269586e+00,
#          1.72784256e+00,   1.75634353e+00,   3.43982110e+00,
#          3.54028011e+00,   4.97748211e+00,   2.16582434e+00,
#          8.15266222e-01,   1.91694579e-01,   3.52901914e+00,
#          1.72065487e+00,   1.49516197e+00,   1.79773392e+00,
#          2.84831487e+00,   1.90619411e+00,   9.28671369e-01,
#          3.33014880e+00,   2.68405539e+00,   2.40423081e+00,
#          2.47752956e+00,   3.06676607e+00,   1.28972408e+00,
#          2.35639144e+00,   2.40892108e+00,   2.04345891e+00,
#          3.08001909e+00,   2.82963325e+00,   3.34126949e+00,
#          3.47302284e+00,   3.26214969e+00,   3.14177419e+00,
#          2.85202593e-01,   7.70201188e-01,   2.34224361e+00,
#          3.53300459e+00,   1.59999610e+00,   2.65191593e+00,
#          2.23751685e+00,   1.03853368e-01,   3.39866057e+00,
#          2.99795522e+00,   3.29613399e-01,   3.73289062e+00,
#          3.37686451e+00,   1.89605774e+00,   2.30001361e+00,
#          3.46841946e+00,   2.24797329e+00,   3.83745020e+00,
#          2.87609752e+00,   2.14250527e+00,   4.61012051e-01,
#          3.24741506e+00,   2.83005413e+00,   3.05759979e+00,
#          5.81820656e-01,   2.29914632e+00,   1.40807772e+00,
#          1.65920359e+00,   3.71904714e-01,   3.45496646e+00,
#          2.85163160e+00,   2.25064727e+00,   3.32462643e+00,
#          2.64276180e+00,   1.18712481e+00,   2.12538467e+00,
#          8.99135997e-01,   2.59778889e+00,   6.18191429e-01,
#          2.52792673e+00,   2.51601194e+00,   2.06830435e+00,
#          3.31236650e+00,   2.89700983e+00,   3.74047011e+00,
#          3.28469186e+00,   1.58883872e+00,   3.00715679e+00,
#          3.12697930e+00,   1.04553602e+00,   2.48702485e+00,
#          1.47607266e+00,   2.61116935e+00,   4.07527418e+00,
#          2.14221485e+00,   3.17851539e+00,   3.99606455e+00,
#          2.18519744e+00,   1.57668585e+00,   6.85636750e-01,
#          2.95473333e-01,   3.52366964e+00,   2.58729485e+00,
#          1.56250075e+00,   1.77330973e+00,   5.08986519e-01,
#          1.35870542e+00,   2.29441265e+00,   8.65905271e-01,
#          1.55852114e+00,   2.70075042e-01,   2.56901709e+00,
#          3.23729945e+00,   2.68192693e+00,   2.20133241e+00,
#          1.10820850e+00,   2.16629980e+00,   1.30768225e+00,
#          1.20505086e+00,   2.50181195e+00,   2.96065695e+00,
#          3.20436549e+00,   7.36080367e-01,   3.22134724e+00,
#          2.60854951e-01,   3.79617043e+00,   2.20734460e+00,
#          2.48412164e+00,   1.63030860e+00,   4.00660018e+00,
#          3.54077193e+00,   1.17511823e+00,   3.62078465e+00,
#          2.74586468e+00,   3.48826051e+00,   1.48868509e+00,
#          1.84154021e+00,   1.81493081e+00,   1.47241980e+00,
#          3.87035302e+00,   2.02801084e+00,   3.84218405e+00,
#          3.31422474e+00,   3.18947434e+00,   2.91228759e+00,
#          2.11189983e+00,   1.23434216e+00,   2.72837093e+00,
#          3.33844479e+00,   3.30701312e-01,   1.36795550e+00,
#          1.66219312e+00,   3.79732221e+00,   1.79009148e-01,
#          3.17532587e+00,   3.10221737e+00,   1.20152302e-01,
#         -2.42842724e-01,   2.33660358e+00,   2.11776780e+00,
#          2.63764563e+00,   2.61235950e-01,   2.33439090e+00,
#          1.85461742e+00,   2.90686497e+00,   2.97362366e+00,
#          1.36864328e+00,   1.66189369e+00,   3.33488180e+00,
#          4.32171354e+00,   2.72479455e+00,   7.96968539e-01,
#          1.80058022e+00,   4.48078700e+00,   3.91125986e+00,
#          3.20303782e+00,   3.54665782e+00,   1.19298107e+00,
#          2.50099253e+00,   4.08228438e+00,   2.43413057e+00,
#          3.48370058e+00,   1.54102273e+00,   2.37584512e+00,
#          7.15422693e-01,   4.57229657e+00,   2.29206331e+00,
#          3.47849688e+00,   1.11142676e+00,   1.69180495e+00,
#          2.73402096e+00,   3.63181427e+00,   2.79806926e+00,
#          2.85968919e+00,   5.24218368e-01,   1.03485652e+00,
#          3.76561714e+00,   2.44392709e+00,   2.68389189e+00,
#          3.22715686e+00,   8.60649867e-01,   2.38101791e+00,
#          1.53425552e+00,   1.24442306e+00,   1.40740787e+00,
#          2.64556052e+00,   6.18467393e-01,   3.38562450e+00,
#          2.72251190e+00,   3.66850877e+00,   3.64774498e+00,
#          3.87105062e+00,   8.54091636e-01,   3.91056458e+00,
#          1.96024202e+00,   4.85578246e-01,   1.86971272e+00,
#          2.13238400e+00,   3.21770993e+00,   2.24875228e+00,
#          6.26010004e-01,   3.53929793e+00,   2.28746301e+00,
#          2.57159293e+00,   2.40829225e+00,   3.65167265e-01,
#          2.26431057e+00,   3.00678577e+00,   1.14005445e+00,
#          3.61152844e+00,   2.15987049e+00,   2.67021243e+00,
#          8.87277139e-01,   1.36843015e+00,   1.68099003e+00,
#          3.76032846e-03,   1.47026509e+00,   1.67197861e+00,
#          8.03661604e-01,   3.33766734e+00,   2.76392422e+00,
#          2.86195880e+00,   3.10128610e+00,   1.29923354e+00,
#          4.29804225e+00,   2.80404493e+00,   2.92989632e+00,
#          3.27244762e+00,   2.81942030e+00,   2.42486657e+00,
#          2.38259399e+00,   6.80448657e-01,   3.65654768e+00,
#          1.92765620e+00,   1.93875315e+00,   2.99541964e+00,
#          3.43879746e+00,   1.30737178e+00,   1.80545275e+00,
#          3.51253935e+00,   2.92488186e-01,   1.87947895e+00,
#          2.70100279e+00,   1.91602401e+00,   2.50965900e+00,
#          2.92970637e+00,   2.88983422e+00,   2.88518909e+00,
#          2.16577389e+00,   2.14075251e+00,   2.74684414e+00,
#          1.26240630e+00,   2.01267054e+00,   3.65056903e+00,
#          4.59970552e+00,   3.31534615e-01,   7.67786760e-01,
#          9.25279642e-01,   2.29128663e+00,   3.16896757e+00,
#          1.61156988e+00,   3.58667773e+00,   3.36136029e+00,
#          3.64779520e+00,   1.22942281e+00,   1.62039558e+00,
#          4.19019898e-01,   2.34840429e+00,   2.62299381e+00,
#          1.54299026e+00,   3.28532774e+00,   2.05695066e+00,
#          4.38224235e+00,   6.71055083e-01,   2.96732964e+00,
#          2.99306290e+00,   3.27621535e+00,   3.15898834e+00,
#          2.97432236e+00,   1.62064016e+00,   1.11197889e+00,
#          3.26886910e+00,   3.99652102e+00,   3.23913025e+00,
#          2.83325278e+00,   1.16735771e+00,   1.68395711e+00,
#          2.48365988e+00,   2.65635382e+00,   3.95406674e+00,
#          1.40698521e+00,   1.67974338e+00,   4.20320255e+00,
#          4.00737244e+00,   3.06883373e+00,   3.16415181e+00,
#          2.46097003e+00,   2.95385779e+00,   2.38310320e+00,
#          7.80303944e-01,   2.43083214e+00,   3.12973602e+00,
#          2.45530736e+00,   2.33531863e+00,   1.64906220e+00,
#          1.04805249e+00,   2.34073966e+00,   2.02361412e+00,
#          2.03721434e+00,   2.81546510e+00,   3.58451864e+00,
#          2.54212998e+00,   1.87695887e+00,   1.81853822e+00,
#          2.76645154e+00,   2.47023738e+00,   2.04698024e+00,
#          2.38168109e+00,   1.67092033e+00,   3.83239432e+00,
#          1.94138006e+00,   2.05961073e+00,   2.63439709e+00,
#          3.66617975e+00,   2.62581593e+00,   1.87407074e+00,
#          2.86715320e+00,   1.27027395e+00,   2.90889177e+00,
#          2.98079477e+00,   1.00762993e+00,   3.54946536e+00,
#          2.08086955e+00,   1.65478156e+00,   1.60153637e+00])

# %%
counts_test
# Out:
# array([ 1.09861229,  2.48490665,  3.36729583,  0.        ,  2.83321334,
#         2.63905733,  3.55534806,  2.07944154,  3.25809654,  3.49650756,
#         2.7080502 ,  4.92725369,  2.63905733,  2.19722458,  2.7080502 ,
#         2.89037176,  2.07944154,  0.        ,  2.19722458,  2.63905733,
#         3.21887582,  3.29583687,  3.09104245,  3.4339872 ,  2.77258872,
#         1.79175947,  0.        ,  2.07944154,  3.33220451,  3.17805383,
#         2.99573227,  0.69314718,  2.83321334,  2.30258509,  0.69314718,
#         0.69314718,  3.93182563,  2.39789527,  3.29583687,  3.49650756,
#         1.09861229,  0.        ,  1.79175947,  0.        ,  3.4657359 ,
#         3.55534806,  2.56494936,  2.56494936,  3.09104245,  2.89037176,
#         1.38629436,  1.38629436,  2.30258509,  1.94591015,  2.99573227,
#         1.38629436,  1.79175947,  3.29583687,  2.19722458,  2.19722458,
#         2.83321334,  1.09861229,  4.02535169,  2.07944154,  1.09861229,
#         2.83321334,  4.11087386,  1.94591015,  1.09861229,  4.04305127,
#         2.19722458,  2.56494936,  3.13549422,  3.21887582,  0.        ,
#         2.19722458,  0.        ,  1.09861229,  2.63905733,  4.69134788,
#         0.        ,  3.04452244,  1.79175947,  3.4339872 ,  1.38629436,
#         0.        ,  0.69314718,  3.63758616,  1.60943791,  2.48490665,
#         3.4339872 ,  3.33220451,  3.91202301,  2.30258509,  0.        ,
#         1.79175947,  0.        ,  1.79175947,  1.09861229,  2.99573227,
#         2.99573227,  2.83321334,  4.4543473 ,  4.00733319,  3.93182563,
#         0.        ,  2.19722458,  3.8918203 ,  3.71357207,  1.09861229,
#         3.04452244,  3.4657359 ,  2.7080502 ,  2.56494936,  1.79175947,
#         3.61091791,  3.4339872 ,  3.21887582,  2.77258872,  2.83321334,
#         0.        ,  2.99573227,  3.29583687,  2.99573227,  4.2341065 ,
#         2.07944154,  4.02535169,  2.89037176,  2.63905733,  2.30258509,
#         2.48490665,  1.38629436,  4.29045944,  2.07944154,  3.4657359 ,
#         0.        ,  2.89037176,  0.69314718,  3.09104245,  2.56494936,
#         3.76120012,  2.94443898,  2.94443898,  3.40119738,  0.        ,
#         2.83321334,  1.60943791,  3.13549422,  3.4657359 ,  1.94591015,
#         3.63758616,  2.63905733,  3.71357207,  3.78418963,  3.52636052,
#         2.89037176,  4.17438727,  2.48490665,  3.66356165,  3.98898405,
#         3.13549422,  1.79175947,  0.        ,  2.63905733,  4.67282883,
#         0.69314718,  0.        ,  1.38629436,  1.79175947,  2.39789527,
#         2.89037176,  2.19722458,  1.09861229,  0.69314718,  1.09861229,
#         1.38629436,  3.40119738,  1.09861229,  2.07944154,  0.        ,
#         4.91265489,  1.38629436,  3.04452244,  1.94591015,  3.4339872 ,
#         3.61091791,  1.79175947,  2.19722458,  3.61091791,  0.69314718,
#         3.33220451,  1.09861229,  2.30258509,  0.        ,  4.30406509,
#         3.8286414 ,  3.80666249,  3.04452244,  0.69314718,  1.79175947,
#         2.19722458,  1.38629436,  2.19722458,  2.56494936,  1.79175947,
#         1.38629436,  2.94443898,  4.09434456,  3.73766962,  1.38629436,
#         2.56494936,  1.09861229,  4.02535169,  0.69314718,  3.33220451,
#         2.30258509,  1.60943791,  4.27666612,  2.07944154,  3.13549422,
#         3.4657359 ,  2.30258509,  3.21887582,  1.09861229,  2.77258872,
#         2.39789527,  0.69314718,  2.48490665,  0.        ,  3.66356165,
#         3.8918203 ,  1.38629436,  3.95124372,  3.8286414 ,  1.38629436,
#         3.8501476 ,  1.94591015,  2.56494936,  4.02535169,  3.63758616,
#         3.78418963,  3.4339872 ,  0.        ,  1.38629436,  3.68887945,
#         3.63758616,  3.40119738,  1.38629436,  2.7080502 ,  5.04985601,
#         4.77068462,  2.07944154,  3.61091791,  4.31748811,  0.        ,
#         3.71357207,  3.36729583,  2.30258509,  3.55534806,  0.        ,
#         2.30258509,  1.79175947,  3.76120012,  2.77258872,  3.4657359 ,
#         1.79175947,  3.66356165,  0.        ,  0.        ,  1.09861229,
#         2.19722458,  1.38629436,  2.63905733,  4.15888308,  3.4657359 ,
#         3.4657359 ,  0.        ,  3.71357207,  0.        ,  2.94443898,
#         3.87120101,  1.94591015,  0.69314718,  0.        ,  3.13549422,
#         3.4339872 ,  3.49650756,  2.94443898,  2.7080502 ,  0.        ,
#         3.80666249,  3.4657359 ,  3.76120012,  0.69314718,  2.48490665,
#         1.79175947,  1.60943791,  0.        ,  0.        ,  3.36729583,
#         0.        ,  2.63905733,  4.70048037,  2.77258872,  2.89037176,
#         2.83321334,  3.78418963,  3.36729583,  2.77258872,  4.51085951,
#         3.21887582,  4.55387689,  3.87120101,  2.63905733,  2.77258872,
#         1.60943791,  3.29583687,  2.77258872,  2.39789527,  2.48490665,
#         2.48490665,  3.4339872 ,  3.76120012,  0.        ,  1.09861229,
#         3.21887582,  1.60943791,  3.13549422,  1.09861229,  2.63905733,
#         0.69314718,  2.77258872,  0.        ,  4.09434456,  1.60943791,
#         0.        ,  1.60943791,  1.09861229,  2.30258509,  2.19722458,
#         1.09861229,  1.60943791,  1.60943791,  3.09104245,  3.61091791,
#         0.        ,  4.04305127,  0.        ,  2.94443898,  1.94591015,
#         2.07944154,  2.99573227,  2.77258872,  1.09861229,  2.7080502 ,
#         2.99573227,  2.30258509,  5.27299956,  3.76120012,  2.99573227,
#         2.56494936,  2.48490665,  2.30258509,  3.33220451,  3.29583687,
#         2.63905733,  3.66356165,  3.58351894,  3.13549422,  2.30258509,
#         2.7080502 ,  2.19722458,  2.63905733,  2.19722458,  3.52636052,
#         2.30258509,  0.69314718,  3.40119738,  0.        ,  3.4657359 ,
#         3.40119738,  2.07944154,  2.83321334,  3.4657359 ,  3.8918203 ,
#         0.69314718,  2.48490665,  3.33220451,  2.63905733,  3.63758616,
#         2.89037176,  3.40119738,  0.        ,  1.94591015,  2.77258872,
#         3.66356165,  2.39789527,  1.60943791,  2.48490665,  2.99573227,
#         0.        ,  2.89037176,  1.38629436,  1.60943791,  3.8501476 ,
#         4.55387689,  1.09861229,  3.87120101,  4.27666612,  3.97029191,
#         2.94443898,  2.39789527,  2.94443898,  3.58351894,  2.89037176,
#         0.69314718,  0.        ,  2.63905733,  2.19722458,  1.94591015])

# %% [markdown]
# #### Playing around with meshgrids and heatmaps

# %%
#    def build_distance_matrix(self, locs1, locs2):
#        lats1 = locs
locs1 = loc_test[:10]
locs2 = loc_test[:10]
lons1, lats1 = locs1[:,0], locs1[:,1]
lons2, lats2 = locs2[:,0], locs2[:,1]

dlon12 = lons2 - lons1[:, None]
dlat12 = lats2 - lats1[:, None]
D12 = np.sqrt(np.square(dlon12*FACTOR) + np.square(dlat12))

# %%
D12*3959/360*(2*math.pi)
# Out:
# array([[ 0.        ,  1.39523079,  1.96471068,  0.71857897,  5.29380988,
#          5.79834312,  2.94676103,  9.92440435,  8.02608894,  4.25992357],
#        [ 1.39523079,  0.        ,  1.11416825,  1.04036259,  3.97240741,
#          4.41131905,  1.65626082,  8.55823393,  6.64770278,  2.89621607],
#        [ 1.96471068,  1.11416825,  0.        ,  1.27424998,  3.47062276,
#          4.17147038,  1.21712554,  8.1481053 ,  6.31001544,  2.58206911],
#        [ 0.71857897,  1.04036259,  1.27424998,  0.        ,  4.68786206,
#          5.27770478,  2.35244664,  9.3496261 ,  7.47610958,  3.70663656],
#        [ 5.29380988,  3.97240741,  3.47062276,  4.68786206,  0.        ,
#          1.15013074,  2.34714639,  4.67808653,  2.88035272,  1.15063785],
#        [ 5.79834312,  4.41131905,  4.17147038,  5.27770478,  1.15013074,
#          0.        ,  2.959904  ,  4.18855454,  2.25055268,  1.58947213],
#        [ 2.94676103,  1.65626082,  1.21712554,  2.35244664,  2.34714639,
#          2.959904  ,  0.        ,  6.99739117,  5.12821883,  1.37155979],
#        [ 9.92440435,  8.55823393,  8.1481053 ,  9.3496261 ,  4.67808653,
#          4.18855454,  6.99739117,  0.        ,  1.94645428,  5.66527983],
#        [ 8.02608894,  6.64770278,  6.31001544,  7.47610958,  2.88035272,
#          2.25055268,  5.12821883,  1.94645428,  0.        ,  3.77127827],
#        [ 4.25992357,  2.89621607,  2.58206911,  3.70663656,  1.15063785,
#          1.58947213,  1.37155979,  5.66527983,  3.77127827,  0.        ]])

# %%
plt.imshow(D12, interpolation='none')
plt.jet()
cb = plt.colorbar()
cb.set_label('distance')
plt.show()

# %%
matplotlib.rcdefaults()

# %%
matplotlib.rcParams.update({'font.size': 14})

# %%
colors = [min(i*1.0/50, 1) for i in counts]
# create new figure, axes instances.
fig=plt.figure(figsize=(20, 20))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
m = Basemap(llcrnrlon=-74.03,llcrnrlat=40.69,urcrnrlon=-73.9,urcrnrlat=40.88,resolution='l',projection='merc',)
#m = Basemap(llcrnrlon=-74.02,llcrnrlat=40.7,urcrnrlon=-73.9,urcrnrlat=40.9,resolution='l',projection='merc',)
m.drawcounties(0.3)
m.drawparallels(np.arange(40.69,40.88,0.03),labels=[1,0,0,1])
m.drawmeridians(np.arange(-74.03,-73.9,0.02),labels=[1,0,0,1])
m.scatter(lon_coords, lat_coords, c=colors, latlon=True)
m.drawmapscale(lon=-73.94, lat=40.70, lon0=-73.97, lat0=40.78,
               barstyle='fancy', units='mi', length=4, fontsize=14, yoffset=(0.01*(m.ymax-m.ymin)))
cb = m.colorbar()
cb.set_ticks([.2, .4, .6, .8, 1])  # force there to be only 5 ticks
cb.set_ticklabels([10, 20, 30, 40, '>50'])  # put text labels on them
ax.set_title('Manhattan collision count by intersection')
#plt.savefig('manhattan3.png', dpi=600)
plt.show()

# %%
colors = [min(i*1.0/50, 1) for i in counts]
# create new figure, axes instances.
fig=plt.figure(figsize=(20, 20))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
m = Basemap(llcrnrlon=-73.98,llcrnrlat=40.75,urcrnrlon=-73.96,urcrnrlat=40.78,resolution='l',projection='merc',)
#m.drawcounties()
m.drawparallels(np.arange(40.75,40.78,0.002),labels=[1,0,0,1])
m.drawmeridians(np.arange(-73.98,-73.96,0.002),labels=[1,0,0,1])
m.scatter(lon_coords, lat_coords, c=colors, latlon=True)
cb = m.colorbar()
cb.set_ticks([.2, .4, .6, .8, 1])  # force there to be only 5 ticks
cb.set_ticklabels([10, 20, 30, 40, '>50'])  # put text labels on them
ax.set_title('Manhattan collision count by intersection')
#plt.savefig('manhattan3.png', dpi=600)
plt.show()

# %%
fig=plt.figure(figsize=(5, 5))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
m = Basemap(llcrnrlon=-74.02,llcrnrlat=40.7,urcrnrlon=-73.9,urcrnrlat=40.9,resolution='l',projection='merc',)
m.drawparallels(np.arange(10,90,0.03),labels=[1,0,0,1])
m.drawmeridians(np.arange(-180,180,0.02),labels=[1,0,0,1])
grid = m.makegrid(3,4)
z = grid[0]+grid[1]
#m.scatter(grid[0], grid[1], latlon=True)
m.imshow(z,interpolation='none')
plt.show()

# %% [markdown]
# #### Yay! Now let's put this together with kriging

# %%
nx = 50
ny = 100
m = Basemap(llcrnrlon=-74.03,llcrnrlat=40.69,urcrnrlon=-73.9,urcrnrlat=40.88,resolution='l',projection='merc',)
grid = m.makegrid(nx,ny)
loc_grid = np.column_stack((grid[0].ravel()[:,None],grid[1].ravel()[:,None]))

# %%
kriger = Kriging(kernel='matern_3', length_scale=0.5, sigma_y = 1, sigma_f = 5)
kriger.fit(loc, log_counts)
grid_predictions = kriger.predict(loc_grid)
grid_predictions.resize((ny,nx))

# %%
fig=plt.figure(figsize=(20, 20))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
m.drawparallels(np.arange(40.69,40.88,0.03),labels=[1,0,0,1])
m.drawmeridians(np.arange(-74.03,-73.9,0.02),labels=[1,0,0,1])
m.imshow(grid_predictions,interpolation='none')
m.drawmapscale(lon=-73.94, lat=40.70, lon0=-73.97, lat0=40.78,
               barstyle='fancy', units='mi', length=4, fontsize=14, yoffset=(0.01*(m.ymax-m.ymin)))
cb = m.colorbar()
cb.set_label('log counts')
ax.set_title('Predicted means from kriging')
plt.show()

# %%
grid_sds = np.sqrt(kriger.variances(loc_grid))
grid_sds.resize((ny,nx))

# %%
fig=plt.figure(figsize=(20, 20))
ax=fig.add_axes([0.1,0.1,0.8,0.8])
#m = Basemap(llcrnrlon=-74.02,llcrnrlat=40.7,urcrnrlon=-73.9,urcrnrlat=40.9,resolution='l',projection='merc',)
m.drawparallels(np.arange(40.69,40.88,0.03),labels=[1,0,0,1])
m.drawmeridians(np.arange(-74.03,-73.9,0.02),labels=[1,0,0,1])
m.imshow(grid_sds,interpolation='none')
m.drawmapscale(lon=-73.94, lat=40.70, lon0=-73.97, lat0=40.78,
               barstyle='fancy', units='mi', length=4, fontsize=14, yoffset=(0.01*(m.ymax-m.ymin)))
cb = m.colorbar()
cb.set_label('log counts')
ax.set_title('Predicted standard deviations from kriging')
plt.show()

# %%
# Steps
# Compute distance matrix (method for this?)
# Compute kernel function (store these all in a kriging class?)
# Do matrix operations
